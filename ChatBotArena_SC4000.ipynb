# %% [markdown]
# <a href="https://colab.research.google.com/github/zelaneroz/CWRU-Coursework/blob/main/ChatBotArena_SC4000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# title, detailed exploratory data analysis (EDA), data cleaning, modeling, and visualizations
